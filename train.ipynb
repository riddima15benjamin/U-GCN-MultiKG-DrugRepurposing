# %%
import pandas as pd
import os

# %%
file_path = r'dataset\CTD_chemicals_diseases.csv'

if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' was not found.")
else:
    # Use pandas to read the regular CSV file
    try:
        df = pd.read_csv(file_path, comment='#') 

        print("File loaded successfully!")
        print("\nDataFrame Info:")
        df.info()

        print("\nFirst 5 rows of the loaded data:")
        print(df.head())

    except Exception as e:
        print(f"An error occurred while loading the file: {e}")
# Out:
# File loaded successfully!
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9515672 entries, 0 to 9515671
# Data columns (total 10 columns):
#  #   Column                                          Dtype
# ---  ------                                          -----
#  0   06-Paris-LA-66 protocol                         object
#  1   C046983                                         object
#  2   Unnamed: 2                                      object
#  3   Precursor Cell Lymphoblastic Leukemia-Lymphoma  object
#  4   MESH:D054198                                    object
#  5   therapeutic                                     object
#  6   Unnamed: 6                                      object
#  7   Unnamed: 7                                      float64
#  8   Unnamed: 8                                      object
#  9   4519131                                         object
# dtypes: float64(1), object(9)
# memory usage: 726.0+ MB
#
# First 5 rows of the loaded data:
#   06-Paris-LA-66 protocol  C046983 Unnamed: 2  \
# 0                10074-G5  C534883        NaN
# 1                10074-G5  C534883        NaN
# 2                10074-G5  C534883        NaN
# 3                10074-G5  C534883        NaN
# 4                10074-G5  C534883        NaN
#
#   Precursor Cell Lymphoblastic Leukemia-Lymphoma     MESH:D054198 therapeutic  \
# 0                                 Adenocarcinoma     MESH:D000230         NaN
# 1                         Adenocarcinoma of Lung  MESH:D000077192         NaN
# 2                                       Alopecia     MESH:D000505         NaN
# 3                Androgen-Insensitivity Syndrome     MESH:D013734         NaN
# 4                                    Astrocytoma     MESH:D001254         NaN
#
#   Unnamed: 6  Unnamed: 7     Unnamed: 8            4519131
# 0        MYC        4.08            NaN           26432044
# 1        MYC        4.31            NaN  26656844|27602772
# 2         AR        4.51            NaN           15902657
# 3         AR        6.88  300068|312300    1303262|8281139
# 4         AR        4.96            NaN           24680642
